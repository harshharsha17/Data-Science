# %% [markdown]
# # **INTRODUCTION TO PYTHON**
# ---
# ## Program
# set of intructions given to the computer to perform any application
# ## python programming
# *   launched in 1991
# *   invented by Guido van Rossum
# *   python is boon now bcoz of data now a days all are working with data
# *   that days application development is boon using java
#
# ## why python
#
#
# *   easy to understand language
# *   **high level** programming language - easy to understand and used by humans
#
# **the language which is understood by machine is called low level language**
# *   interpreted language
#
# **executed line by line**
# *   expressive language
# *   general purpose programming language
#
# **it works in all domains like ai,ml,web dev....** but how?? bcoz **python has lots of library support thats the reason why its used in major domains**

# %%
print("Harsha Vardhini")
# Out:
# Harsha Vardhini

# %% [markdown]
# ## Variable
# its a container where the actual data is stored
# ## data types
# it defines in which form the data is stored

# %%
d1=10
d2=12.225
d3="python"
d4=True

# %% [markdown]
# type() its going to tell me type of data

# %%
print(d1,type(d1))
print(d2,type(d2))
print(d3,type(d3))
print(d4,type(d4))
# Out:
# 10 <class 'int'>
# 12.225 <class 'float'>
# python <class 'str'>
# True <class 'bool'>

# %% [markdown]
# **list:** identify by []
#
# **tuple:** identify by ()
#
# **set:** identify by {}
#
# **dictionary:** identify by {} but store value in the form of key:value

# %%
d_set={199,45,78,227}
print(d_set)
print(type(d_set))
# Out:
# {227, 45, 78, 199}
# <class 'set'>

# %% [markdown]
# set() is unorder

# %%
d_list=[21,679,924,7,8]
print(d_list)
print(type(d_list))
# Out:
# [21, 679, 924, 7, 8]
# <class 'list'>

# %%
d_tuple=(21,679,924,7,8)
print(d_tuple)
print(type(d_tuple))
# Out:
# (21, 679, 924, 7, 8)
# <class 'tuple'>

# %%
d_dict={"name":"harsha","age":20}
print(d_dict)
print(type(d_dict))
# Out:
# {'name': 'harsha', 'age': 20}
# <class 'dict'>
