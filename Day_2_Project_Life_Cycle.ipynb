# %% [markdown]
# ## **What exactly data scientist wil do??**
# ### Roles and Responsibilities:
# ---

# %% [markdown]
# # **PROJECT LIFE CYCLE**
#  ![Screenshot 2025-07-31 220734.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# ### **FRAME THE PROBLEM**
#
#
# *   Clearly define the business problem
# *   collaborate with stakeholders
# *   ask key questions to identify the objective

# %% [markdown]
# ---
#
#
# ### **COLLECTING AND READING DATA**
#
#
# *   collect the data and read the data into ML tools like R,python..
# *   You should check which type of data you are using like its structured ,unstructured

# %% [markdown]
# ---
#
#
# ### **EXPLORATORY DATA ANALYSIS**
#
#
# *   understanding the data rows=records,columns=variables
#
# *   histogram
# *   bar graph
# *   box plot
# *   scatter plot
# *   pie chart
# *   identify target variables - dependent variables and independent variables in the dataset
# *   using visualization and statistics to detect patterns,

# %% [markdown]
# ---
#
#
# ### **DATA CLEANING/PREPROCESSING**
#
#
# *   Handling missing data
# *   managing unwanted outliers
# *   fixing structural errors
# *   removal of unwanted observations like dropping irrevelent columns or rows

# %% [markdown]
# ---
#
#
# ### what is machine learning?
#
# training our machine
#
# developing a model for x and y

# %% [markdown]
# ---
#
#
# ### **DATA TRANSFORMATION**
#
#
# *   Normalize or scale the numeric data (ex: log tranform,exponential tranformation)
# *   Apply pca for dimensionality reduction
#
#
# *   Use one hot encoding for categorical features

# %% [markdown]
# ---
#
#
# ### **DATA PARTITION**
#
#
# *   we are splitting the data into training - known data and testing - unknown data dataset
# *   splits data into
#
#       training set - model building
#
#       testing set - model validation
# *   ensures the model performance is evaluated on unseen data

# %% [markdown]
# ---
#
#
# ### **SELECT THE MODEL**
# we are having lots of models so we need to select which model is suitable for our dataset

# %% [markdown]
# ---
#
#
# ### **CROSS VALIDATION**
#
#
# *   cv -- to avoid overfitting
# *   perform hyperparameter tuning ex: gridsearch,randomsearch
#
#
# *   validate models with multiple random splits of the data

# %% [markdown]
# ---
#
#
# ### **MODEL EVALUATION**
#
#
# *   use metrics depending on the task
#       regression:R^2,RMSE
#       classification: accuracy,f1 score,auc,log loss
# *   compare models and select the best performing one

# %% [markdown]
# ---
#
#
# ### **PREDICTION AND DEPLOYMENT**
#
#
# *   train the best model on the full training data
# *   use the model to predict outcomes on real world data
#
#
# *   integrate the model into production environments for business dat
# *   List item
#
#
#
#
#
# ---
